# %%
from wordcloud import WordCloud, ImageColorGenerator
from PIL import Image
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
resposta ="""
reliability and stability of the developed software complexity in simple tasks
the guarantee of documentation the addition of demands to the development process although it is natural it wears in the development process it is not going versions as they change a lot all developers should understand a little about the process to reduce resistance in the adoption of guidelines continuous integration branch merge the team should have an introduction to the process before starting development
the developer should perform the unit tests of the code he the developer runs automated tests test the system manually disseminate if the method has more than 15 lines it should be doing more than thing
because the requirements document was by the developers themselves i believe the document end up not representing the client's needs i did not the complete architecture document the of all pylint standards makes development difficult the warnings are not very clear in addition external libraries generate warnings when they do not follow these standards the dependency control system it works better than the python requirement pylint i wasted a lot of time trying to fix the warnings
i learned about tools that help both in creating the virtual environment poetry as the structure of tools to help in development although documentation is extremely necessary
i have no way to respond because this was developed already at the end of the implementation together with the development team and not with the project owner it was necessary that when the standards were established there was total team training with the tools to be
the standards are elaborated but there is a lot of demand and little time for deliveries it becomes totally unfeasible to follow all the standards it was not put into practice precisely lack of time i liked dependency management there are standards but some are not being followed for some reasons some standards were created after development was already underway scarce time for developing a complex system managers should be more agile and assertive in decision-making and more detailed regarding the system's requirements this facilitate development and enable the created standards
integrated development environment with github commit standardization and code review tools the lack of a code quality review stage that would signal which of the code the improved""".lower()


lista_preposicao = ["none", "\n", ".\n", ".", "\'s", "\""]
for i in lista_preposicao:
  resposta = resposta.replace(f"{i}", " ")


# plot grafico
wordcloud = WordCloud(max_font_size=40).generate(resposta)
plt.figure()
plt.imshow(wordcloud, interpolation="bilinear")
plt.axis("off")
plt.show()

# conta palavras
dict_respostas = dict.fromkeys(set(resposta.split(" ")), 0)
for i in resposta.split(" "):
  dict_respostas[i] += 1

dict_respostas
# Out:
# {'': 3,
#  'were': 2,
#  'decision-making': 1,
#  'reliability': 1,
#  'unfeasible': 1,
#  'learned': 1,
#  'review': 2,
#  'by': 1,
#  'managers': 1,
#  'external': 1,
#  'he': 1,
#  'these': 1,
#  'into': 1,
#  'deliveries': 1,
#  'developer': 2,
#  'being': 1,
#  'needs': 1,
#  'tasks': 1,
#  'standardization': 1,
#  'complex': 1,
#  'the': 40,
#  'developing': 1,
#  'it': 8,
#  'lines': 1,
#  'total': 1,
#  '15': 1,
#  'integration': 1,
#  'for': 3,
#  'github': 1,
#  'i': 6,
#  'addition': 2,
#  'more': 4,
#  'signal': 1,
#  'help': 2,
#  'believe': 1,
#  'elaborated': 1,
#  'underway': 1,
#  'agile': 1,
#  'implementation': 1,
#  'together': 1,
#  'adoption': 1,
#  'than': 3,
#  'demand': 1,
#  'put': 1,
#  'to': 8,
#  'at': 1,
#  'be': 3,
#  'python': 1,
#  'with': 4,
#  'do': 1,
#  'precisely': 1,
#  'pylint': 2,
#  'creating': 1,
#  'control': 1,
#  'developed': 2,
#  'lot': 3,
#  'all': 3,
#  'team': 3,
#  'if': 1,
#  'natural': 1,
#  'end': 2,
#  'test': 1,
# ...

# %%
import numpy as np
import matplotlib.pyplot as plt
import matplotlib as mpl
from wordcloud import WordCloud

text ="""
reliability and stability of the developed software complexity in simple tasks
the guarantee of documentation the addition of demands to the development process although it is natural it wears in the development process it is not going versions as they change a lot all developers should understand a little about the process to reduce resistance in the adoption of guidelines continuous integration branch merge the team should have an introduction to the process before starting development
the developer should perform the unit tests of the code he the developer runs automated tests test the system manually disseminate if the method has more than 15 lines it should be doing more than thing
because the requirements document was by the developers themselves i believe the document end up not representing the client's needs i did not the complete architecture document the of all pylint standards makes development difficult the warnings are not very clear in addition external libraries generate warnings when they do not follow these standards the dependency control system it works better than the python requirement pylint i wasted a lot of time trying to fix the warnings
i learned about tools that help both in creating the virtual environment poetry as the structure of tools to help in development although documentation is extremely necessary
i have no way to respond because this was developed already at the end of the implementation together with the development team and not with the project owner it was necessary that when the standards were established there was total team training with the tools to be
the standards are elaborated but there is a lot of demand and little time for deliveries it becomes totally unfeasible to follow all the standards it was not put into practice precisely lack of time i liked dependency management there are standards but some are not being followed for some reasons some standards were created after development was already underway scarce time for developing a complex system managers should be more agile and assertive in decision-making and more detailed regarding the system's requirements this facilitate development and enable the created standards
integrated development environment with github commit standardization and code review tools the lack of a code quality review stage that would signal which of the code the improved""".lower()

bola_mask = np.array(Image.open("/content/circulo-preto-1.jpg"))


color_map = mpl.colors.ListedColormap(["lightskyblue", "orangered"])

wc = WordCloud(background_color="white", repeat=True, mask=bola_mask, colormap= color_map)
wc.generate(text)

# fig1 = plt.figure(dpi= 1000)


plt.axis("off")
plt.imshow(wc, interpolation="bilinear")

plt.savefig('example.pdf', dpi = 1000, format="pdf", bbox_inches='tight')
plt.show()
