# %%
from wordcloud import WordCloud, ImageColorGenerator
from PIL import Image
import matplotlib.pyplot as plt
import numpy as np
import matplotlib.pyplot as plt
from wordcloud import WordCloud

# %%
resposta ="""
complexity in simple tasks. the addition of demands to the development process. despite being natural, it generates wear and tear in the development process. things aren't going well. branch merge. the team must have an introduction to the process before starting development. test system manually pylint. i lost a lot of time trying to fix the warnings despite extremely necessary the documentations there are standards, but some are not being followed for some reasons: a) some standards were created after development was already being carried out; b) scant time for development of a complex system. the lack of a step of code quality review that signal which parts of the code still can/should be improved. it wasn't put into practice precisely because of lack of time versions because they change a lot the developer must write the unit tests of the code he wrote didn't see the complete architecture document the use of all pylint standards makes the development difficult. once that the warnings are not very clear. besides external libraries also generate warnings when they don't follow these standards due to the fact that the requirements document was filled out by the developers themselves, i believe that the document can end up not representing the needs of the client""".lower()


lista_preposicao = ["none", "\n", ".\n", ".", "\'s", "\""]
for i in lista_preposicao:
  resposta = resposta.replace(f"{i}", " ")


# plot grafico
wordcloud = WordCloud(max_font_size=40).generate(resposta)
plt.figure()
plt.imshow(wordcloud, interpolation="bilinear")
plt.axis("off")
plt.show()

# conta palavras
dict_respostas = dict.fromkeys(set(resposta.split(" ")), 0)
for i in resposta.split(" "):
  dict_respostas[i] += 1

dict_respostas
# Out:
# {'': 12,
#  'test': 1,
#  'out;': 1,
#  'warnings': 3,
#  'are': 3,
#  'improved': 1,
#  'all': 1,
#  'documentations': 1,
#  'practice': 1,
#  'addition': 1,
#  'were': 1,
#  'these': 1,
#  'be': 1,
#  'up': 1,
#  'going': 1,
#  'starting': 1,
#  'was': 2,
#  'before': 1,
#  'into': 1,
#  'very': 1,
#  'of': 11,
#  'needs': 1,
#  'difficult': 1,
#  'b)': 1,
#  'some': 3,
#  'step': 1,
#  'merge': 1,
#  'development': 6,
#  'introduction': 1,
#  'requirements': 1,
#  'the': 22,
#  'i': 2,
#  'developers': 1,
#  'it': 2,
#  'lost': 1,
#  'time': 3,
#  'can': 1,
#  'clear': 1,
#  'due': 1,
#  'precisely': 1,
#  'complexity': 1,
#  'see': 1,
#  'lack': 2,
#  'believe': 1,
#  'branch': 1,
#  'architecture': 1,
#  'pylint': 2,
#  'wear': 1,
#  'can/should': 1,
#  'to': 4,
#  'external': 1,
#  'team': 1,
#  'tests': 1,
#  'things': 1,
#  'reasons:': 1,
#  'despite': 2,
#  'generates': 1,
#  'review': 1,
#  'they': 2,
#  'filled': 1,
#  'change': 1,
#  'use': 1,
#  'natural,': 1,
# ...

# %%
text_ruim="""
complexity in simple tasks. the addition of demands to the development process. despite being natural, it generates wear and tear in the development process. things aren't going well. branch merge. the team must have an introduction to the process before starting development. test system manually pylint. i lost a lot of time trying to fix the warnings despite extremely necessary the documentations there are standards, but some are not being followed for some reasons: a) some standards were created after development was already being carried out; b) scant time for development of a complex system. the lack of a step of code quality review that signal which parts of the code still can/should be improved. it wasn't put into practice precisely because of lack of time versions because they change a lot the developer must write the unit tests of the code he wrote didn't see the complete architecture document the use of all pylint standards makes the development difficult. once that the warnings are not very clear. besides external libraries also generate warnings when they don't follow these standards due to the fact that the requirements document was filled out by the developers themselves, i believe that the document can end up not representing the needs of the client managers must be more agile and accurate in decision-making and more detailed about system requirements. this will facilitate development and enable the use of created standards""".lower()

text_bom= """managers must be more agile and accurate in decision-making and more detailed about system requirements. this will facilitate development and enable the use of created standards. reliability and stability of the developed software. documentation assurance. continuous integration running automated tests the dependency control system. it works better than python's requirement. i learned about tools that help in creating the virtual environment like poetry, as well as the tool structure to aid in development. i liked dependency management integrated development environment with github, commit standardization tools, and code review. all developers should understand a bit about the process to reduce resistance in adopting guidelines 'maybe it would be necessary that, when standards are established, there is a full team training on the tools to be used. the standards are well developed, but there is much demand and little time for deliveries, thus it becomes totally unfeasible to follow all standards.' i have no way to respond. because this was developed already at the end of the implementation together with the development team and not with the 'owner' of the project."""

bola_mask = np.array(Image.open("forma_tubarao.jpg"))


# color_map = mpl.colors.ListedColormap(["autumn", "Blues"])

wc = WordCloud(background_color="white", repeat=True, mask=bola_mask, colormap= "autumn")
wc.generate(text_ruim)

# fig1 = plt.figure(dpi= 1000)


plt.axis("off")
plt.imshow(wc, interpolation="bilinear")

plt.savefig('example.pdf', dpi = 1000, format="pdf", bbox_inches='tight')
plt.show()


lista_preposicao = ["none", "\n", ".\n", ".", "\'s", "\""]
for i in lista_preposicao:
  resposta = resposta.replace(f"{i}", " ")
  
# conta palavras
dict_respostas = dict.fromkeys(set(text_bom.split(" ")), 0)
for i in resposta.split():
    if i in dict_respostas:
        dict_respostas[i] += 1

dict_respostas
# Out:
# {'must': 2,
#  'end': 1,
#  'already': 1,
#  'unfeasible': 0,
#  "standards.'": 0,
#  'of': 11,
#  'becomes': 0,
#  'managers': 0,
#  'it': 2,
#  'code': 3,
#  'little': 0,
#  'poetry,': 0,
#  'will': 0,
#  'adopting': 0,
#  'process': 3,
#  'a': 4,
#  'respond.': 0,
#  'detailed': 0,
#  'necessary': 1,
#  'full': 0,
#  'facilitate': 0,
#  'environment': 0,
#  'team': 1,
#  'works': 0,
#  'tool': 0,
#  'enable': 0,
#  'totally': 0,
#  'well': 1,
#  'dependency': 0,
#  'integration': 0,
#  'requirement.': 0,
#  'there': 1,
#  'are': 3,
#  'was': 2,
#  'running': 0,
#  'understand': 0,
#  'created': 1,
#  'standards': 3,
#  'tools,': 0,
#  'training': 0,
#  'standardization': 0,
#  'have': 1,
#  'control': 0,
#  'liked': 0,
#  'more': 0,
#  'at': 0,
#  'implementation': 0,
#  'structure': 0,
#  'requirements.': 0,
#  'this': 0,
#  'system': 2,
#  'integrated': 0,
#  'established,': 0,
#  'like': 0,
#  'for': 2,
#  'developed': 0,
#  'be': 1,
#  'standards.': 0,
#  'stability': 0,
# ...

# %%
cacao ="Mordida Menos-agressivos Imagem-violenta Ataques Tubarão predador Pequenos Tubarão Mordidas Tubarão Mordidas Perigoso Filhote Tubarão Acidentes Desconhecimento Tubarão Mordidas Tubarão Tubarão Inofensivo Tubarão-Filhote Mordidas Filhotes Mordidas Filhote Medo Ataques Tubarão Agressivo Tubarão-Filhote Medo Agressivo Traiçoeiro Tubarão Tubarão-Filhote Mordidas Predador Mordidas Violento"

arraia = "Desconhecimento Ferrão acidente Fofas Ferrão Ferrão picada Ferrão Ferrão Ataques Acidentes Camuflagem Ferrão Queimadura Ferrão Venenosa Ferrão Ferrão matar Predador Ferrão Ferrão toxina Ferrão Ferrão Ferrão camuflagem Ferrão perigosa Queimadura Acidentes Ferrão Ferrão Morte Ferrão veneno Desconhecimento Ferrão Ferrão Veneno Ferrão Ferrão Ferrão Fofas Ferrão Ferrão Pré-conceito Ferrão Veneno ferimento Ferrão Fofas Espinho Ferrão Inofensiva Acidentes Veneno Ferrão Ataques Ferrão Perigo Ferrão Ferrão Ataques Ferrão Calmas Dóceis Linda Ferrão veneno Ferrão Linda Ferrão Ferrão Veneno Ferrão Ferrão Ferrão Bonita Perigosa Ferrão Ferrão Ferrão Ferrão Acidentes Ferrão Veneno Ataques Dóceis"

ecológica Equilíbrio-ecossistêmico Equilíbrio-ecossistêmico Equilíbrio-ecossistêmico Manutenção-trófica Controle-populacional Predadores Importantes Vida-marinha Manutenção-trófica Predadores Conservação Filtradores Equilíbrio-ecossistêmico Predadores Equilíbrio-ecossistêmico Equilíbrio-ecossistêmico Equilíbrio-ecossistêmico Equilíbrio-ecossistêmico Manutenção-trófica Equilíbrio-ecossistêmico Equilíbrio-ecossistêmico Equilíbrio-ecossistêmico Controle-populacional Equilíbrio-ecossistêmico Equilíbrio-ecossistêmico Manutenção-trófica Equilíbrio-ecossistêmico Equilíbrio-ecossistêmico Controle-populacional Controle-populacional Equilíbrio-ecossistêmico Regulação-marinha Equilíbrio-ecossistêmico Biodiversidade Equilíbrio-ecossistêmico Controle-ecológico Equilíbrio-ecossistêmico Equilíbrio-ecossistêmico"

importancia2 = "Equilíbrio_ecossistêmico Manutenção_trófica Equilíbrio_ecossistêmico Predadores Conservação_ambiental Manutenção_trófica Equilíbrio_ecossistêmico Manutenção_trófica Proteção_marinha Saúde_marinha Equilíbrio_ecossistêmico Controle_populacional Controle_populacional Equilíbrio_ecossistêmico Equilíbrio_ecossistêmico Controle_populacional Manutenção_trófica Equilíbrio_ecossistêmico Controle_populacional Equilíbrio_ecossistêmico Controle_populacional Saúde_marinha Biodiversidade Equilíbrio_ecossistêmico Controle_populacional Equilíbrio_ecossistêmico Equilíbrio_ecossistêmico Controle_populacional Manutenção_trófica Equilíbrio_ecossistêmico Controle_populacional Equilíbrio_ecossistêmico Controle_populacional Equilíbrio_ecossistêmico Controle_populacional Economia_tradicional Controle_populacional Equilíbrio_ecossistêmico Controle_populacional Predadores Escavação Equilíbrio_ecossistêmico Controle_populacional Controle_populacional Equilíbrio_ecossistêmico Vida_marinha Equilíbrio_ecossistêmico Rede_ecológica Equilíbrio_ecossistêmico Equilíbrio_ecossistêmico Equilíbrio_ecossistêmico Manutenção_trófica Controle_populacional Predadores Importantes Vida_marinha Manutenção_trófica Predadores Conservação Filtradores Equilíbrio_ecossistêmico Predadores Equilíbrio_ecossistêmico Equilíbrio_ecossistêmico Equilíbrio_ecossistêmico Equilíbrio_ecossistêmico Manutenção_trófica Equilíbrio_ecossistêmico Equilíbrio_ecossistêmico Equilíbrio_ecossistêmico Controle_populacional Equilíbrio_ecossistêmico Equilíbrio_ecossistêmico Manutenção_trófica Equilíbrio_ecossistêmico Equilíbrio_ecossistêmico Controle_populacional Controle_populacional Equilíbrio_ecossistêmico Regulação_marinha Equilíbrio_ecossistêmico Biodiversidade Equilíbrio_ecossistêmico Controle_ecológico Equilíbrio_ecossistêmico Equilíbrio_ecossistêmico"

text = importancia2

# Máscara da imagem
# bola_mask = np.array(Image.open("./forma_tubarao.jpg"))
bola_mask = np.array(Image.open("./forma_nuvem.jpg"))

# Criação da nuvem com resolução aumentada
wc = WordCloud(
    background_color="white",
    repeat=False,
    mask=bola_mask,
    collocations=True,
    # collocation_threshold=3,
    prefer_horizontal=2,
    # font_step= 1,
    colormap="brg",
    # colormap="Dark2",
    relative_scaling=0.1,
    # colormap="winter",
    width=300,
    height=300
)


wc.generate(text)



# # tamanho cacao
plt.figure(figsize=(10, 10))


# Plotar
plt.axis("off")
plt.imshow(wc, interpolation="bilinear")

# Salvar com alta resolução
# plt.savefig('tubarao.jpeg', dpi=600, format="jpeg", bbox_inches='tight')
plt.show()
